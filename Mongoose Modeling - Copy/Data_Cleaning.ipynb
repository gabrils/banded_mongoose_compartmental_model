# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
# %matplotlib inline
import seaborn as sns
sns.set()
from matplotlib.backends.backend_pdf import PdfPages
#from mpl_toolkits.basemap import Basemap
import matplotlib.cm as cm
import matplotlib.colors as col
import matplotlib as mpl
import numpy as np #import for transposing
import math
import pylab as pl
#import mpld3 as ml
import random

# %%
data_count = pd.read_csv('../Mongoose Modeling/tbl_Data_Count.csv')
data_count.head()
# Out:
#    ObservationID  S Total  Uncert ST  S Male  Uncert SM  S Female  Uncert SF  \
# 0  air0911191652      4.0        2.0     NaN        NaN       NaN        NaN
# 1  air1008260805     10.0        1.0     3.0        NaN       4.0        NaN
# 2  air1011221150      7.0        2.0     3.0        2.0       4.0        2.0
# 3  air1101130810     12.0        2.0     NaN        NaN       NaN        NaN
# 4  bdf1008111030     20.0        2.0     NaN        NaN       NaN        NaN
#
#    S Unknown  Uncert SU  S Adult  \
# 0        NaN        NaN      NaN
# 1        3.0        NaN      5.0
# 2        NaN        NaN      7.0
# 3        NaN        NaN      7.0
# 4        NaN        NaN      NaN
#
#                          ...                          Uncert ISU  I Juvenile  \
# 0                        ...                                 NaN         NaN
# 1                        ...                                 NaN         NaN
# ...

# %%
data_count.columns
# Out:
# Index(['ObservationID', 'S Total', 'Uncert ST', 'S Male', 'Uncert SM',
#        'S Female', 'Uncert SF', 'S Unknown', 'Uncert SU', 'S Adult',
#        'Uncert SA', 'S Adult Male', 'Uncert SAM', 'S Adult Female',
#        'Uncert SAF', 'S Adult Female Preg', 'Uncert SAFP',
#        'S Adult Female Lactating', 'Uncert SAFL',
#        'S Adult Female Enlarged Nip', 'Uncert SAFEN', 'S Adult Unknown',
#        'Uncert SAU', 'S SubAd', 'Uncert SS', 'S SubAd Male', 'Uncert SSM',
#        'S SubAd Female', 'Uncert SSF', 'S SubAd Unknown', 'Uncert SSU',
#        'S Juvenile', 'Uncert SJ', 'S Juvenile Male', 'Uncert SJM',
#        'S Juvenile Female', 'Uncert SJF', 'S Juvenile Unknown', 'Uncert SJU',
#        'I Total', 'Uncert IT', 'I Male', 'Uncert IM', 'I Female', 'Uncert IF',
#        'I Unknown', 'Uncert IU', 'I Adult', 'Uncert IA', 'I Adult Male',
#        'Uncert IAM', 'I Adult Female', 'Uncert IAF', 'I Adult Female Preg',
# ...

# %% [markdown]
# <b>Removing entirely empty rows (search based on empty total count columns)</b>

# %%
total = data_count[['S Total','I Total']]
total
# Out:
#       S Total  I Total
# 0         4.0      NaN
# 1        10.0      NaN
# 2         7.0      NaN
# 3        12.0      NaN
# 4        20.0      NaN
# 5        15.0      NaN
# 6        23.0      NaN
# 7        25.0      NaN
# 8         NaN      NaN
# 9        15.0      NaN
# 10       20.0      NaN
# 11       30.0      NaN
# 12        NaN      NaN
# 13       21.0      NaN
# 14       31.0      NaN
# 15        NaN      NaN
# 16        7.0      NaN
# 17       37.0      NaN
# 18       34.0      NaN
# 19       33.0      NaN
# 20       18.0      NaN
# 21       35.0      NaN
# 22       36.0      NaN
# 23       37.0      0.0
# 24       31.0      NaN
# 25       17.0      NaN
# 26       36.0      NaN
# 27       13.0      NaN
# 28       34.0      NaN
# 29       33.0      NaN
# ...       ...      ...
# 1987      8.0      NaN
# 1988      8.0      NaN
# 1989      5.0      NaN
# 1990      3.0      NaN
# 1991      3.0      NaN
# 1992      7.0      NaN
# 1993      NaN      NaN
# 1994      3.0      1.0
# ...

# %%
counts = data_count.drop(['ObservationID','IndividualsObserved'],axis = 1)
empty_total = counts[['S Total','I Total']]

# %%
empty = counts.loc[(empty_total['S Total'].isnull()) & (empty_total['I Total'].isnull())]
empty
# Out:
#       S Total  Uncert ST  S Male  Uncert SM  S Female  Uncert SF  S Unknown  \
# 8         NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 12        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 15        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 36        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 42        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 43        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 44        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 45        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 46        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 47        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 48        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# ...

# %%
empty[empty.isnull() == False]
# Out:
#       S Total  Uncert ST  S Male  Uncert SM  S Female  Uncert SF  S Unknown  \
# 8         NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 12        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 15        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 36        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 42        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 43        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 44        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 45        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 46        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 47        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# 48        NaN        NaN     NaN        NaN       NaN        NaN        NaN
# ...

# %%
Change=np.zeros((8,4))
Change[0,:] = [1, 2, 3, 0]
np.sum(Change[0,:])
# Out:
# 6.0
